# %%
a= input()
print (a)
# Out:
# 1 2 3 4
# 1 2 3 4

# %%
a= int(input())
print(type(a))
# Out:
# 1
# <class 'int'>

# %%
a=bin(65)
print(a)
# Out:
# 0b1000001

# %%
a="15"
print(str(a))
# Out:
# 15

# %%
a=('1234')
print(a)
# Out:
# 1234

# %%
print(float('1.5'))
# Out:
# 1.5

# %%
a=65
print(isinstance(a,object))
# Out:
# True

# %%
a='A'
print(isinstance(a,object))
# Out:
# True
